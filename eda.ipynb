# %% [markdown]
# # Eurovision Song Contest Data
#
# The dataset contains voting and polling data for the six most recent editions of the Eurovision Song Contest (2022, 2021, 2019, 2018, 2017, and 2016).

# %%
import pandas as pd

# %% [markdown]
# ## Voting Data
#
# The dataset contains data on how different countries allocated their points in Eurovision finals.
#
# Each participating country awards two sets of **12**, **10**, **8–1** points to their ten favourite songs: one set from their professional jury and the other from televoting.

# %% [markdown]
# ### Jury Data
#
# Each cell contains the number of points awarded by the column country's jury to the row country.

# %%
def get_jury_data(year):
    path = f"./data/Final Results/Jury/{year}_jury_results.csv"
    df = pd.read_csv(path, index_col="Contestant")
    df = df.iloc[:, 3:]
    return df


jury_data = get_jury_data(2022)

jury_data
# Out:
#                 Netherlands  San Marino  North Macedonia  Malta  Ukraine  \
# Contestant
# Czech Republic          NaN         NaN              NaN    3.0      1.0
# Romania                 NaN         NaN              NaN    NaN      NaN
# Portugal                8.0         NaN              NaN    NaN     10.0
# Finland                 NaN         NaN              NaN    NaN      NaN
# Switzerland            10.0         1.0              1.0    NaN      6.0
# France                  NaN         NaN              NaN    NaN      NaN
# Norway                  3.0         NaN              NaN    NaN      NaN
# Armenia                 NaN         NaN              NaN    NaN      2.0
# Italy                   NaN         3.0              7.0    7.0      NaN
# Spain                   5.0        12.0             12.0   12.0      NaN
# Netherlands             NaN         NaN              NaN    NaN      8.0
# Ukraine                 NaN         2.0              NaN    NaN      NaN
# Germany                 NaN         NaN              NaN    NaN      NaN
# Lithuania               NaN         NaN              NaN    NaN      NaN
# Azerbaijan              NaN         7.0              4.0    2.0      5.0
# Belgium                 6.0         NaN              3.0    NaN      NaN
# Greece                 12.0        10.0              NaN    1.0      7.0
# Iceland                 NaN         NaN              NaN    NaN      NaN
# Moldova                 2.0         NaN              NaN    NaN      NaN
# Sweden                  1.0         5.0              6.0   10.0      4.0
# Australia               7.0         6.0              5.0    6.0      3.0
# United Kingdom          4.0         8.0              8.0    8.0     12.0
# Poland                  NaN         4.0              2.0    4.0      NaN
# Serbia                  NaN         NaN             10.0    NaN      NaN
# Estonia                 NaN         NaN              NaN    5.0      NaN
#
#                 Albania  Estonia  Azerbaijan  Portugal  Germany  ...  Georgia  \
# Contestant                                                       ...
# Czech Republic      NaN      NaN         NaN       NaN      NaN  ...      NaN
# Romania             NaN      NaN         NaN       NaN      1.0  ...      NaN
# Portugal            1.0      7.0         7.0       NaN      NaN  ...      7.0
# Finland             NaN      5.0         NaN       NaN      NaN  ...      NaN
# Switzerland         NaN      NaN         NaN       2.0      2.0  ...      NaN
# France              NaN      NaN         1.0       NaN      NaN  ...      1.0
# Norway              NaN      NaN         NaN       NaN      3.0  ...      NaN
# Armenia             4.0      NaN         NaN       1.0      NaN  ...      NaN
# Italy              12.0     10.0        10.0       NaN      NaN  ...     10.0
# Spain               5.0      NaN         5.0      12.0      8.0  ...      5.0
# Netherlands         6.0      1.0         4.0       7.0      4.0  ...      4.0
# Ukraine             7.0      NaN         6.0       8.0     10.0  ...      6.0
# Germany             NaN      NaN         NaN       NaN      NaN  ...      NaN
# Lithuania           NaN      2.0         NaN       5.0      NaN  ...      NaN
# Azerbaijan          3.0      3.0         NaN       NaN      6.0  ...      NaN
# Belgium             2.0      NaN         NaN       NaN      NaN  ...      NaN
# Greece              NaN      6.0         3.0       4.0      NaN  ...      3.0
# Iceland             NaN      NaN         NaN       6.0      NaN  ...      NaN
# Moldova             NaN      NaN         NaN       NaN      NaN  ...      NaN
# Sweden              8.0     12.0         8.0       NaN      7.0  ...      8.0
# Australia           NaN      8.0         NaN       NaN      5.0  ...      NaN
# United Kingdom     10.0      4.0        12.0      10.0     12.0  ...     12.0
# Poland              NaN      NaN         2.0       NaN      NaN  ...      2.0
# Serbia              NaN      NaN         NaN       3.0      NaN  ...      NaN
# Estonia             NaN      NaN         NaN       NaN      NaN  ...      NaN
#
#                 Croatia  Lithuania  Austria  Finland  United Kingdom  Sweden  \
# Contestant
# Czech Republic      NaN        NaN      NaN      NaN             NaN     5.0
# Romania             NaN        NaN      NaN      NaN             NaN     NaN
# Portugal           10.0        8.0     10.0      NaN             3.0     NaN
# Finland             NaN        NaN      NaN      NaN             NaN     NaN
# Switzerland         1.0        7.0      1.0      NaN             2.0     NaN
# France              NaN        NaN      NaN      NaN             NaN     NaN
# Norway              NaN        NaN      5.0      4.0             NaN     3.0
# Armenia             NaN        NaN      6.0      1.0             NaN     2.0
# Italy               4.0        4.0      3.0      2.0             NaN     NaN
# Spain               6.0        5.0      2.0      NaN            10.0    12.0
# Netherlands         2.0        6.0      8.0      5.0             NaN     NaN
# Ukraine             8.0       12.0      NaN      NaN             NaN     NaN
# Germany             NaN        NaN      NaN      NaN             NaN     NaN
# Lithuania           7.0        NaN      NaN      NaN             NaN     NaN
# Azerbaijan          NaN        NaN      NaN      3.0             7.0     7.0
# Belgium             NaN        NaN      NaN      NaN             NaN     1.0
# Greece              3.0        NaN      4.0      6.0             4.0     NaN
# Iceland             NaN        2.0      NaN      NaN             NaN     NaN
# Moldova             NaN        NaN      NaN      NaN             NaN     NaN
# Sweden              5.0        3.0      7.0     12.0            12.0     NaN
# Australia           NaN        NaN      NaN      8.0             6.0    10.0
# United Kingdom      NaN       10.0     12.0     10.0             NaN     8.0
# Poland              NaN        NaN      NaN      NaN             8.0     NaN
# Serbia             12.0        1.0      NaN      7.0             1.0     4.0
# Estonia             NaN        NaN      NaN      NaN             5.0     6.0
#
#                 Australia  Czech Republic  Italy
# Contestant
# Czech Republic        4.0             NaN    NaN
# Romania               NaN             NaN    NaN
# Portugal              6.0             5.0    NaN
# Finland               NaN             NaN    1.0
# Switzerland           NaN             6.0    3.0
# France                NaN             NaN    NaN
# Norway                NaN             2.0    NaN
# Armenia               NaN             NaN    8.0
# Italy                 3.0             NaN    NaN
# Spain                12.0             7.0    NaN
# Netherlands           NaN             NaN   12.0
# Ukraine               7.0             4.0    NaN
# Germany               NaN             NaN    NaN
# Lithuania             NaN             NaN    NaN
# Azerbaijan            2.0             NaN    NaN
# Belgium               5.0             NaN    7.0
# Greece                NaN             3.0   10.0
# Iceland               NaN             NaN    NaN
# Moldova               NaN             NaN    5.0
# Sweden               10.0            10.0    NaN
# Australia             NaN             1.0    2.0
# United Kingdom        NaN            12.0    6.0
# Poland                NaN             NaN    NaN
# Serbia                8.0             NaN    4.0
# Estonia               1.0             8.0    NaN
#
# [25 rows x 40 columns]

# %% [markdown]
# ### Jury Data
#
# Each cell contains the number of points awarded by the column country's public to the row country.

# %%
def get_televote_data(year):
    path = f"./data/Final Results/Televote/{year}_televote_results.csv"
    df = pd.read_csv(path, index_col="Contestant")
    df = df.iloc[:, 3:]
    return df


televote_data = get_televote_data(2022)

televote_data
# Out:
#                 Netherlands  San Marino  North Macedonia  Malta  Ukraine  \
# Contestant
# Czech Republic          NaN         NaN              5.0    NaN      NaN
# Romania                 NaN         1.0              NaN    3.0      NaN
# Portugal                NaN         NaN              NaN    NaN      NaN
# Finland                 NaN         NaN              NaN    1.0      4.0
# Switzerland             NaN         NaN              NaN    NaN      NaN
# France                  NaN         NaN              NaN    NaN      NaN
# Norway                  5.0         2.0              2.0    4.0      2.0
# Armenia                 NaN         NaN              NaN    NaN      NaN
# Italy                   NaN         5.0              6.0   10.0      NaN
# Spain                   7.0        10.0             10.0    7.0      1.0
# Netherlands             NaN         NaN              NaN    NaN      3.0
# Ukraine                12.0        12.0              8.0    8.0      NaN
# Germany                 NaN         NaN              NaN    NaN      NaN
# Lithuania               NaN         NaN              1.0    NaN     10.0
# Azerbaijan              NaN         NaN              NaN    NaN      NaN
# Belgium                 4.0         NaN              NaN    NaN      NaN
# Greece                  NaN         7.0              NaN    NaN      NaN
# Iceland                 NaN         NaN              NaN    NaN      8.0
# Moldova                10.0         4.0              7.0    NaN      6.0
# Sweden                  2.0         3.0              4.0    5.0      NaN
# Australia               NaN         NaN              NaN    NaN      NaN
# United Kingdom          8.0         6.0              NaN   12.0      7.0
# Poland                  6.0         NaN              NaN    2.0     12.0
# Serbia                  3.0         8.0             12.0    6.0      NaN
# Estonia                 1.0         NaN              3.0    NaN      5.0
#
#                 Albania  Estonia  Azerbaijan  Portugal  Germany  ...  Georgia  \
# Contestant                                                       ...
# Czech Republic      NaN      NaN         NaN       NaN      NaN  ...      NaN
# Romania             NaN      NaN         NaN       NaN      NaN  ...      NaN
# Portugal            NaN      NaN         NaN       NaN      NaN  ...      NaN
# Finland             2.0      8.0         NaN       NaN      NaN  ...      2.0
# Switzerland         NaN      NaN         NaN       NaN      NaN  ...      NaN
# France              NaN      NaN         NaN       NaN      NaN  ...      NaN
# Norway              NaN      4.0         7.0       2.0      1.0  ...      NaN
# Armenia             NaN      NaN         NaN       NaN      NaN  ...     10.0
# Italy               8.0      NaN         5.0       3.0      3.0  ...      NaN
# Spain               7.0      1.0        10.0      10.0      2.0  ...      6.0
# Netherlands         6.0      3.0         NaN       4.0      4.0  ...      NaN
# Ukraine            10.0     12.0        12.0      12.0     12.0  ...     12.0
# Germany             NaN      2.0         NaN       NaN      NaN  ...      NaN
# Lithuania           NaN      7.0         NaN       1.0      NaN  ...      5.0
# Azerbaijan          NaN      NaN         NaN       NaN      NaN  ...      3.0
# Belgium             NaN      NaN         NaN       NaN      NaN  ...      NaN
# Greece             12.0      NaN         3.0       NaN      NaN  ...      1.0
# Iceland             NaN      NaN         NaN       NaN      NaN  ...      NaN
# Moldova             1.0      6.0         NaN       8.0     10.0  ...      8.0
# Sweden              NaN     10.0         4.0       7.0      5.0  ...      NaN
# Australia           NaN      NaN         2.0       NaN      NaN  ...      NaN
# United Kingdom      4.0      5.0         8.0       6.0      6.0  ...      4.0
# Poland              NaN      NaN         1.0       NaN      8.0  ...      NaN
# Serbia              3.0      NaN         6.0       5.0      7.0  ...      7.0
# Estonia             5.0      NaN         NaN       NaN      NaN  ...      NaN
#
#                 Croatia  Lithuania  Austria  Finland  United Kingdom  Sweden  \
# Contestant
# Czech Republic      NaN        NaN      NaN      NaN             NaN     NaN
# Romania             NaN        NaN      NaN      NaN             3.0     NaN
# Portugal            NaN        7.0      NaN      NaN             NaN     NaN
# Finland             NaN        NaN      NaN      NaN             NaN     7.0
# Switzerland         NaN        NaN      NaN      NaN             NaN     NaN
# France              1.0        NaN      NaN      1.0             NaN     NaN
# Norway              5.0        2.0      5.0      6.0             6.0    10.0
# Armenia             NaN        NaN      NaN      NaN             NaN     NaN
# Italy               6.0        3.0      3.0      NaN             NaN     NaN
# Spain               7.0        6.0      1.0      3.0             5.0     2.0
# Netherlands         NaN        1.0      NaN      NaN             NaN     1.0
# Ukraine            10.0       12.0     12.0     12.0            12.0    12.0
# Germany             NaN        NaN      2.0      NaN             NaN     NaN
# Lithuania           3.0        NaN      NaN      2.0             7.0     3.0
# Azerbaijan          NaN        NaN      NaN      NaN             NaN     NaN
# Belgium             NaN        NaN      NaN      NaN             NaN     NaN
# Greece              NaN        NaN      NaN      NaN             NaN     NaN
# Iceland             NaN        NaN      NaN      NaN             NaN     NaN
# Moldova             8.0        5.0      7.0      5.0             8.0     NaN
# Sweden              4.0       10.0      6.0      8.0             4.0     NaN
# Australia           NaN        NaN      NaN      NaN             NaN     NaN
# United Kingdom      NaN        4.0      8.0      4.0             NaN     6.0
# Poland              NaN        NaN      4.0      NaN            10.0     5.0
# Serbia             12.0        NaN     10.0      7.0             1.0     8.0
# Estonia             2.0        8.0      NaN     10.0             2.0     4.0
#
#                 Australia  Czech Republic  Italy
# Contestant
# Czech Republic        NaN             NaN    NaN
# Romania               NaN             NaN    8.0
# Portugal              NaN             NaN    1.0
# Finland               NaN             1.0    NaN
# Switzerland           NaN             NaN    NaN
# France                NaN             NaN    NaN
# Norway               10.0             3.0    4.0
# Armenia               NaN             NaN    NaN
# Italy                 1.0             NaN    NaN
# Spain                 6.0             6.0    NaN
# Netherlands           NaN             NaN    2.0
# Ukraine              12.0            12.0   12.0
# Germany               NaN             NaN    NaN
# Lithuania             2.0             NaN    NaN
# Azerbaijan            NaN             NaN    NaN
# Belgium               NaN             NaN    NaN
# Greece                NaN             NaN    NaN
# Iceland               NaN             NaN    NaN
# Moldova               4.0             8.0   10.0
# Sweden                5.0             5.0    5.0
# Australia             NaN             NaN    NaN
# United Kingdom        7.0             2.0    6.0
# Poland                3.0             7.0    3.0
# Serbia                8.0            10.0    7.0
# Estonia               NaN             4.0    NaN
#
# [25 rows x 40 columns]

# %% [markdown]
# ## Polling Data

# %% [markdown]
# ### Eurovision World Poll
#
# Every year [Eurovision World](https://eurovisionworld.com/) carries out a poll where users can select which country they believe will win Eurovision.
#
# Users can only vote once for a single country. The dataset contains the number of votes awarded to each country.

# %%
def get_eurovision_world_data(year):
    path = f"./data/Polls/Eurovision World Poll/{year}_eurovisionworld_results.csv"
    return pd.read_csv(path)


eurovision_world_data = get_eurovision_world_data(2022)

eurovision_world_data
# Out:
#          Contestant  Votes
# 0           Ukraine  24631
# 1             Spain  24585
# 2            Sweden  23073
# 3             Italy  21213
# 4    United Kingdom  18484
# 5            Serbia  16544
# 6            Greece  14267
# 7          Portugal  13492
# 8            Poland  12445
# 9       Netherlands  12345
# 10           Norway   8522
# 11          Armenia   7234
# 12           France   6140
# 13        Lithuania   5358
# 14          Finland   4592
# 15          Moldova   4365
# 16          Romania   4179
# 17       Azerbaijan   4151
# 18          Belgium   3607
# 19          Albania   3438
# 20          Estonia   3120
# 21        Australia   3046
# 22           Cyprus   2794
# 23            Malta   2731
# 24          Austria   2300
# 25   Czech Republic   2286
# 26          Iceland   2265
# 27           Israel   1887
# 28         Bulgaria   1796
# 29          Ireland   1745
# 30          Germany   1653
# 31           Latvia   1597
# 32  North Macedonia   1501
# 33         Slovenia   1446
# 34       Montenegro   1436
# 35      Switzerland   1257
# 36          Croatia   1233
# 37       San Marino   1014
# 38          Denmark   1013
# 39          Georgia    764

# %% [markdown]
# ### Organisation Générale des Amateurs de l'Eurovision (OGAE) Poll
#
# Every year [OGAE](https://ogaeinternational.org/) carries out a poll where users can award points to the countries of their top 10 songs (akin to the Eurovision points system).
#
# The dataset contains the average number of points awarded to each country.

# %%
def get_ogae_data(year):
    path = f"./data/Polls/OGAE Poll/{year}_ogae_results.csv"
    return pd.read_csv(path)


ogae_data = get_ogae_data(2022)

ogae_data
# Out:
#          Contestant  Average Points
# 0            Sweden            9.14
# 1             Italy            9.00
# 2             Spain            6.84
# 3       Netherlands            5.07
# 4    United Kingdom            4.74
# 5            France            4.07
# 6            Poland            3.35
# 7            Norway            2.79
# 8           Albania            2.05
# 9           Austria            1.70
# 10          Ukraine            1.40
# 11           Cyprus            1.37
# 12          Estonia            1.26
# 13           Serbia            1.23
# 14           Greece            0.88
# 15          Finland            0.86
# 16   Czech Republic            0.81
# 17        Australia            0.37
# 18        Lithuania            0.26
# 19         Portugal            0.21
# 20           Latvia            0.16
# 21          Moldova            0.14
# 22          Croatia            0.09
# 23          Belgium            0.05
# 24          Germany            0.05
# 25            Malta            0.05
# 26          Romania            0.05
# 27      Switzerland            0.02
# 28          Armenia            0.00
# 29       Azerbaijan            0.00
# 30         Bulgaria            0.00
# 31          Denmark            0.00
# 32          Georgia            0.00
# 33          Iceland            0.00
# 34          Ireland            0.00
# 35           Israel            0.00
# 36       Montenegro            0.00
# 37  North Macedonia            0.00
# 38       San Marino            0.00
# 39         Slovenia            0.00
